# %% [markdown]
# Q 1. version of weights and bias

# %%
import wandb
# !wandb --version
# Out:
# wandb, version 0.15.3

# %% [markdown]
# Q 2. Down and Preprocess the data

# %% [raw]
# Done in Terminal
#
# '''
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-03.parquet
# '''

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/dell/.netrc
# True

# %%
# !python preprocess_data.py \
  --wandb_project TaxiNYC \
  --wandb_entity yiyichanmyaewinshein \
  --raw_data_path ./data/ \
  --dest_path ./output
# Out:
# wandb: Currently logged in as: yiyichanmyaewinshein. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_003427-zoip02mw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run iconic-meadow-1
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/zoip02mw
# wandb: Adding directory to artifact (./output)... Done. 0.0s

# %% [markdown]
# ![The size of DictVectorizer is](./images/dv.png)

# %% [markdown]
# Q 3. Train a model with weights and bias loggin

# %%
# !python train.py \
  --wandb_project TaxiNYC \
  --wandb_entity yiyichanmyaewinshein \
  --data_artifact "yiyichanmyaewinshein/TaxiNYC/NYC-Taxi:v0"
# Out:
# wandb: Currently logged in as: yiyichanmyaewinshein. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_004702-neyb5rd2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run usual-vortex-2
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/neyb5rd2
# wandb:   4 of 4 files downloaded.

# %% [markdown]
# ![The value of max_depth parameter ](./images/max_depth.png)

# %% [markdown]
# Q 4. Tune model hyperparameters

# %%
# !python sweep.py \
  --wandb_project TaxiNYC \
  --wandb_entity yiyichanmyaewinshein \
  --data_artifact "yiyichanmyaewinshein/TaxiNYC/NYC-Taxi:v0"
# Out:
# wandb: \ 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# Create sweep with ID: uaojlmn3
# Sweep URL: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/sweeps/uaojlmn3
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Agent Starting Run: ioxbu2a5 with config:
# wandb: 	max_depth: 9
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 6
# wandb: 	n_estimators: 40
# wandb: / 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Currently logged in as: yiyichanmyaewinshein. Use `wandb login --relogin` to force relogin
# wandb: / 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_005842-ioxbu2a5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pretty-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🧹 View sweep at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/sweeps/uaojlmn3
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/ioxbu2a5
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:   4 of 4 files downloaded.
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45379
# wandb:
# wandb: 🚀 View run pretty-sweep-1 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/ioxbu2a5
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_005842-ioxbu2a5/logs
# wandb: \ 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Agent Starting Run: 0jsl47f5 with config:
# wandb: 	max_depth: 12
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 7
# wandb: 	n_estimators: 42
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_005910-0jsl47f5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run easy-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🧹 View sweep at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/sweeps/uaojlmn3
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/0jsl47f5
# wandb: \ 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:   4 of 4 files downloaded.
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44966
# wandb:
# wandb: 🚀 View run easy-sweep-2 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/0jsl47f5
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_005910-0jsl47f5/logs
# wandb: \ 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Agent Starting Run: nkrm7cdc with config:
# wandb: 	max_depth: 11
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 8
# wandb: 	n_estimators: 43
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_005941-nkrm7cdc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run honest-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🧹 View sweep at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/sweeps/uaojlmn3
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/nkrm7cdc
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:   4 of 4 files downloaded.
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45007
# wandb:
# wandb: 🚀 View run honest-sweep-3 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/nkrm7cdc
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_005941-nkrm7cdc/logs
# wandb: \ 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Agent Starting Run: 5ochjyka with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 8
# wandb: 	n_estimators: 47
# wandb: / 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: \ Waiting for wandb.init()...
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_010009-5ochjyka
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run solar-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🧹 View sweep at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/sweeps/uaojlmn3
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/5ochjyka
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:   4 of 4 files downloaded.
# wandb: / 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44919
# wandb:
# wandb: 🚀 View run solar-sweep-4 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/5ochjyka
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_010009-5ochjyka/logs
# wandb: - 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Agent Starting Run: zna4k40j with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 8
# wandb: 	n_estimators: 36
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/dell/Documents/zoomcamp_datatalks2023/homework/homework2_wandb/wandb/run-20230607_010041-zna4k40j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run treasured-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC
# wandb: 🧹 View sweep at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/sweeps/uaojlmn3
# wandb: 🚀 View run at https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/zna4k40j
# wandb: / 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:   4 of 4 files downloaded.
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 1.430 MB of 1.430 MB uploaded (0.000 MB deduped)
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45062
# wandb:
# wandb: 🚀 View run treasured-sweep-5 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/zna4k40j
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_010041-zna4k40j/logs
# wandb: 🚀 View run iconic-meadow-1 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/zoip02mw
# wandb: Synced 6 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_003427-zoip02mw/logs
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45398
# wandb:
# wandb: 🚀 View run usual-vortex-2 at: https://wandb.ai/yiyichanmyaewinshein/TaxiNYC/runs/neyb5rd2
# wandb: Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230607_004702-neyb5rd2/logs

# %% [markdown]
# Q 5. Link the best model to the model registry

# %%
![model registry](./images/model_re)
